# %%
import numpy as np
import matplotlib.pyplot as plt
start = 100
width = 100
fre = 5000000
timeslide = 1/fre

# %%
f0 = np.fromfile(open("B200_74"), dtype = np.complex64)
f1 = np.fromfile(open("B200_63"), dtype=np.complex64)
f2 = np.fromfile(open("usrp_2"), dtype=np.complex64)

# %%
X = [x*timeslide for  x in np.arange(10000)]

# %%
Y1 = [x.real for x in f1[7500000:28000000]]
plt.plot(X, Y1, color='red')
plt.show()

# %%
Y2 = [x.real for x in f2[8780000:8790000]]
# Y2 = [x.imag for x in f[:15000]]

plt.plot(X, Y2, color='red')
plt.show()
